# %% [markdown]
# ### 1. Importing libraries

# %%
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import requests

# %% [markdown]
# ### 2. Scraping the tree

# %%
titles = []
rates = []
years = []
genres = []

for i in range(1,100):
    r = requests.get(f"https://www.filmaffinity.com/es/vod_dvd.php?eid=filmin&page={str(i)}&ord=rating&genre=")
    soup = BeautifulSoup(r.text, "html.parser")
    rate = [a.get("data-avg") for a in soup.findAll("a", {"class": "movie-wrapper"})]
    title = [a.get("data-movie-t") for a in soup.findAll("a", {"class": "movie-wrapper"})]
    year = [a.get("data-year") for a in soup.findAll("a", {"class": "movie-wrapper"})]
    genre = [a.get("data-genres") for a in soup.findAll("a", {"class": "movie-wrapper"})]
    titles.extend(title)
    rates.extend(rate)
    years.extend(year)
    genres.extend(genre)

# %% [markdown]
# ### 3. Create the dataframe and export to csv

# %%
df_film = pd.DataFrame(
    {'Titles': titles,
     'Rate': rates,
     'Year': years,     
     'Description':genres
    })


df_film = df_film.drop_duplicates("Titles")
df_film
# Out:
#                                             Description Rate  \
# 0     Documental. Serie de TV. Naturaleza. Documenta...  8,7
# 1     Comedia. Romance. Cine mudo. Pobreza. Comedia ...  8,6
# 2     Comedia. Sátira. Nazismo. II Guerra Mundial. P...  8,6
# 3     Comedia. Sátira. Comedia dramática. Drama soci...  8,6
# 4     Drama. Siglo XVII. Japón feudal. Samuráis. Pel...  8,5
# 5     Aventuras. Drama. Japón feudal. Siglo XVI. Sam...  8,5
# 6     Documental. Serie de TV. Miniserie de TV. Natu...  8,4
# 7     Cine negro. Thriller. Intriga. Drama. Crimen. ...  8,4
# 8     Comedia. Drama. Pobreza. Cine mudo. Comedia dr...  8,4
# 9     Drama. Romance. Drama romántico. Melodrama. Ex...  8,4
# 10    Comedia. Drama. Aventuras. Cine mudo. Años 190...  8,4
# 11     Drama. Melodrama. Cine dentro del cine. Infancia  8,3
# 12    Thriller. Intriga. Crimen. Asesinos en serie. ...  8,3
# 13          Drama. Enfermedad. Vejez. Drama psicológico  8,3
# 14    Drama. Histórico. Cine mudo. Siglo XV. Religió...  8,3
# 15    Comedia. Acción. Trenes/Metros. Ejército. Guer...  8,3
# 16    Drama. Romance. Drama romántico. Teatro. Balle...  8,3
# 17                                Drama. Vejez. Familia  8,3
# 18                    Drama. Intriga. Película de culto  8,3
# 19    Drama. Religión. Años 20. Vida rural. Remake. ...  8,3
# 20                  Cine negro. Intriga. Drama. Amistad  8,3
# 21    Bélico. Drama. Guerra de Vietnam. Película de ...  8,3
# 22    Ciencia ficción. Drama. Distopía. Steampunk. R...  8,2
# 23    Drama. Familia. Pobreza. Infancia. Años 1910-1919  8,2
# 24                    Drama. Prostitución. Neorrealismo  8,2
# 25                         Comedia. Sátira. Guerra Fría  8,2
# 26    Drama. Drama carcelario. Nazismo. II Guerra Mu...  8,2
# 27    Drama. Terror. Discapacidad. Circo. Película d...  8,2
# 28        Drama. Expresionismo alemán. Cine mudo. Vejez  8,2
# 29            Intriga. Drama psicológico. Comedia negra  8,2
# ...                                                 ...  ...
# 5094  Terror. Ciencia ficción. Monstruos. Cómic. Mar...  2,5
# 5095                               Comedia. Inmigración  2,5
# 5096     Drama. Drama psicológico. Cine dentro del cine  2,5
# 5097  Terror. Ciencia ficción. Gore. Zombis. Secuela...  2,4
# 5098      Comedia. Terror. Comedia de terror. Monstruos  2,4
# 5099                                            Drama.   2,4
# 5100  Terror. Ciencia ficción. Falso documental. Ext...  2,4
# 5101                                   Comedia. Secuela  2,4
# 5102                               Terror. Sobrenatural  2,3
# 5103                 Terror. Animales. Arañas. Insectos  2,3
# 5104                                     Terror. Zombis  2,3
# 5105                                         Thriller.   2,3
# 5106  Fantástico. Aventuras. Acción. Fantasía mediev...  2,3
# 5107                Terror. Thriller. Vampiros. Serie B  2,2
# 5108  Infantil. Comedia. Animales. Perros/Lobos. Cin...  2,2
# 5109                        Drama. Adolescencia. Drogas  2,2
# 5110                         Comedia. Acción. Policíaco  2,2
# 5111                     Comedia. Comedia negra. Crimen  2,2
# 5112  Terror. Comedia. Gore. Serie B. Comedia de terror  2,2
# 5113            Terror. Monstruos. Serpientes. Telefilm  2,1
# 5114                      Comedia. Cine dentro del cine  2,1
# 5115  Intriga. Thriller. Terror. Thriller psicológic...  2,1
# 5116                           Drama. Cine experimental  2,1
# 5117  Comedia. Drama. Romance. Comedia romántica. Co...  2,1
# 5118                                            Drama.   2,0
# 5119        Acción. Ciencia ficción. Insectos. Telefilm  2,0
# 5120                                          Comedia.   1,9
# 5121                    Comedia. Colegios & Universidad  1,9
# 5122                                            Drama.   1,8
# 5123                    Ciencia ficción. Drama. Erótico  1,7
#
#                                            Titles  Year
# 0                            Cosmos (Serie de TV)  1980
# 1                             Luces de la ciudad   1931
# 2                               El gran dictador   1940
# 3                               Tiempos modernos   1936
# 4                             Harakiri (Seppuku)   1962
# 5                             Los siete samuráis   1954
# 6                Planeta humano (Miniserie de TV)  2011
# 7                           El infierno del odio   1963
# 8                                       El chico   1921
# 9                                       Amanecer   1927
# 10                            La quimera del oro   1925
# 11                               Cinema Paradiso   1988
# 12                   M, el vampiro de Düsseldorf   1931
# 13                                 Vivir (Ikiru)   1952
# 14                    La pasión de Juana de Arco   1928
# 15                   El maquinista de La General   1926
# 16                                    Candilejas   1952
# 17                              Cuentos de Tokio   1953
# 18                                        Rebeca   1940
# 19                            Ordet (La palabra)   1955
# 20                              El tercer hombre   1949
# 21                                Apocalypse Now   1979
# 22                                    Metrópolis   1927
# 23       Pather Panchali (La canción del camino)   1955
# 24                         Las noches de Cabiria   1957
# 25                                Uno, dos, tres   1961
# 26          Un condenado a muerte se ha escapado   1956
# 27                    La parada de los monstruos   1932
# 28                                     El último   1924
# 29                                     La huella   1972
# ...                                           ...   ...
# 5094          Man-Thing. La naturaleza del miedo   2005
# 5095                                 Five Colors   2011
# 5096                       Sombras de Nueva York   2013
# 5097          El día de los muertos II: Contagio   2005
# 5098                               Monster Brawl   2011
# 5099                              The Leftlovers   2014
# 5100                                    Area 407   2011
# 5101            Mr Bones 2: Hechicero del pasado   2008
# 5102                       Bajo aguas tranquilas   2005
# 5103                                    Arachnid   2001
# 5104       Meteletsa: El invierno de los muertos   2012
# 5105                    El hijo bastardo de Dios   2015
# 5106    En el nombre del rey 3: La última misión   2014
# 5107  Hermandad de sangre (Brotherhood of Blood)   2007
# 5108             Bailey: una fortuna muy perruna   2005
# 5109                           Mentiras y gordas   2009
# 5110                      Operasiones espesiales   2014
# 5111                                      Hienas   2009
# 5112                            Jodidos kabrones   2012
# 5113                             Pirañaconda (TV)  2012
# 5114                                  The Lobito   2013
# 5115                                          88   2012
# 5116             Nunca he estado en Poughkeepsie   2013
# 5117                                 Diet of Sex   2014
# 5118                                    Hot Milk   2005
# 5119                        Avispas asesinas (TV)  2012
# 5120                                   Mirabilis   2015
# 5121                                Pledge This!   2006
# 5122                        El viaje de Penélope   2010
# 5123                                         SeX   2004
#
# [5014 rows x 4 columns]

# %%
print(f"Number of titles: {len(df_film.Titles)}")
# Out:
# Number of titles: 5014

# %%
df_film.describe()
# Out:
#        Description  Rate              Titles  Year
# count         5014  5014                5014  5014
# unique        3498    71                5014   105
# top        Drama.    6,7  God Help the Girl   2013
# freq           281   226                   1   277

# %%
df_film.to_csv("filmaffinity.csv", encoding = 'utf-8', index= False)
